# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.feature_selection import SelectFromModel
from sklearn.metrics import mean_squared_error, r2_score
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('/content/sample_data/Walmart Data Analysis and Forcasting.csv')

# %%
df.head()
# Out:
#    Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1  05-02-2010    1643690.90             0        42.31       2.572
# 1      1  12-02-2010    1641957.44             1        38.51       2.548
# 2      1  19-02-2010    1611968.17             0        39.93       2.514
# 3      1  26-02-2010    1409727.59             0        46.63       2.561
# 4      1  05-03-2010    1554806.68             0        46.50       2.625
#
#           CPI  Unemployment
# 0  211.096358         8.106
# 1  211.242170         8.106
# 2  211.289143         8.106
# 3  211.319643         8.106
# 4  211.350143         8.106

# %%
df.isnull().sum()
# Out:
# Store           0
# Date            0
# Weekly_Sales    0
# Holiday_Flag    0
# Temperature     0
# Fuel_Price      0
# CPI             0
# Unemployment    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6435 entries, 0 to 6434
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         6435 non-null   int64
#  1   Date          6435 non-null   object
#  2   Weekly_Sales  6435 non-null   float64
#  3   Holiday_Flag  6435 non-null   int64
#  4   Temperature   6435 non-null   float64
#  5   Fuel_Price    6435 non-null   float64
#  6   CPI           6435 non-null   float64
#  7   Unemployment  6435 non-null   float64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 402.3+ KB

# %%
df.describe()
# Out:
#              Store  Weekly_Sales  Holiday_Flag  Temperature   Fuel_Price  \
# count  6435.000000  6.435000e+03   6435.000000  6435.000000  6435.000000
# mean     23.000000  1.046965e+06      0.069930    60.663782     3.358607
# std      12.988182  5.643666e+05      0.255049    18.444933     0.459020
# min       1.000000  2.099862e+05      0.000000    -2.060000     2.472000
# 25%      12.000000  5.533501e+05      0.000000    47.460000     2.933000
# 50%      23.000000  9.607460e+05      0.000000    62.670000     3.445000
# 75%      34.000000  1.420159e+06      0.000000    74.940000     3.735000
# max      45.000000  3.818686e+06      1.000000   100.140000     4.468000
#
#                CPI  Unemployment
# count  6435.000000   6435.000000
# mean    171.578394      7.999151
# std      39.356712      1.875885
# min     126.064000      3.879000
# 25%     131.735000      6.891000
# 50%     182.616521      7.874000
# 75%     212.743293      8.622000
# max     227.232807     14.313000

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (6435, 8)

# %%
df['Date']=pd.to_datetime(df['Date'],format='%d-%m-%Y')

# %%
df
# Out:
#       Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1 2010-02-05    1643690.90             0        42.31       2.572
# 1         1 2010-02-12    1641957.44             1        38.51       2.548
# 2         1 2010-02-19    1611968.17             0        39.93       2.514
# 3         1 2010-02-26    1409727.59             0        46.63       2.561
# 4         1 2010-03-05    1554806.68             0        46.50       2.625
# ...     ...        ...           ...           ...          ...         ...
# 6430     45 2012-09-28     713173.95             0        64.88       3.997
# 6431     45 2012-10-05     733455.07             0        64.89       3.985
# 6432     45 2012-10-12     734464.36             0        54.47       4.000
# 6433     45 2012-10-19     718125.53             0        56.47       3.969
# 6434     45 2012-10-26     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# 0     211.096358         8.106
# 1     211.242170         8.106
# 2     211.289143         8.106
# 3     211.319643         8.106
# 4     211.350143         8.106
# ...          ...           ...
# 6430  192.013558         8.684
# 6431  192.170412         8.667
# 6432  192.327265         8.667
# 6433  192.330854         8.667
# 6434  192.308899         8.667
#
# [6435 rows x 8 columns]

# %%
import numpy as np
df['log_weekly_sales'] = np.log1p(df['Weekly_Sales'])

# %%
df.head()
# Out:
#    Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1 2010-02-05    1643690.90             0        42.31       2.572
# 1      1 2010-02-12    1641957.44             1        38.51       2.548
# 2      1 2010-02-19    1611968.17             0        39.93       2.514
# 3      1 2010-02-26    1409727.59             0        46.63       2.561
# 4      1 2010-03-05    1554806.68             0        46.50       2.625
#
#           CPI  Unemployment  log_weekly_sales
# 0  211.096358         8.106         14.312455
# 1  211.242170         8.106         14.311400
# 2  211.289143         8.106         14.292967
# 3  211.319643         8.106         14.158908
# 4  211.350143         8.106         14.256862

# %%
df['Weekly_Sales'].describe()
# Out:
# count    6.435000e+03
# mean     1.046965e+06
# std      5.643666e+05
# min      2.099862e+05
# 25%      5.533501e+05
# 50%      9.607460e+05
# 75%      1.420159e+06
# max      3.818686e+06
# Name: Weekly_Sales, dtype: float64

# %% [markdown]
# | Metric  | Value         | Meaning                          |
# | ------- | ------------- | -------------------------------- |
# | Mean    | **1,046,965** | Avg weekly sales ≈ **10.5 lakh** |
# | Median  | **960,746**   | Typical store sells ~9.6 lakh    |
# | Std Dev | **564,367**   | Very high variability            |
# | Min     | **209,986**   | Lowest sales week                |
# | Max     | **3,818,686** | Peak sales (likely holidays)     |

# %%
df['week'] = df['Date'].dt.isocalendar().week
df['month'] = df['Date'].dt.month
df['year'] = df['Date'].dt.year

# %% [markdown]
# Why time features?
#
# 1.Sales depend on seasonality
#
# 2.Holidays don’t occur randomly
#
# 3.Models need numeric signals

# %%
df
# Out:
#       Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1 2010-02-05    1643690.90             0        42.31       2.572
# 1         1 2010-02-12    1641957.44             1        38.51       2.548
# 2         1 2010-02-19    1611968.17             0        39.93       2.514
# 3         1 2010-02-26    1409727.59             0        46.63       2.561
# 4         1 2010-03-05    1554806.68             0        46.50       2.625
# ...     ...        ...           ...           ...          ...         ...
# 6430     45 2012-09-28     713173.95             0        64.88       3.997
# 6431     45 2012-10-05     733455.07             0        64.89       3.985
# 6432     45 2012-10-12     734464.36             0        54.47       4.000
# 6433     45 2012-10-19     718125.53             0        56.47       3.969
# 6434     45 2012-10-26     760281.43             0        58.85       3.882
#
#              CPI  Unemployment  log_weekly_sales  week  month  year
# 0     211.096358         8.106         14.312455     5      2  2010
# 1     211.242170         8.106         14.311400     6      2  2010
# 2     211.289143         8.106         14.292967     7      2  2010
# 3     211.319643         8.106         14.158908     8      2  2010
# 4     211.350143         8.106         14.256862     9      3  2010
# ...          ...           ...               ...   ...    ...   ...
# 6430  192.013558         8.684         13.477482    39      9  2012
# 6431  192.170412         8.667         13.505523    40     10  2012
# 6432  192.327265         8.667         13.506898    41     10  2012
# 6433  192.330854         8.667         13.484401    42     10  2012
# 6434  192.308899         8.667         13.541445    43     10  2012
#
# [6435 rows x 12 columns]

# %%
df.shape
# Out:
# (6435, 12)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6,4))
plt.boxplot(df['Weekly_Sales'], vert=False)
plt.title('Boxplot of Weekly Sales')
plt.show()

# %%
# !pip install statsmodels
import statsmodels
from statsmodels.tsa.seasonal import seasonal_decompose as ssd
ssd(df.Weekly_Sales,period=52).plot()
ssd(df['Weekly_Sales'], model='multiplicative', period=52).seasonal[:52].plot()
# Out:
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.12/dist-packages (0.14.6)
# Requirement already satisfied: numpy<3,>=1.22.3 in /usr/local/lib/python3.12/dist-packages (from statsmodels) (2.0.2)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in /usr/local/lib/python3.12/dist-packages (from statsmodels) (1.16.3)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in /usr/local/lib/python3.12/dist-packages (from statsmodels) (2.2.2)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.12/dist-packages (from statsmodels) (1.0.2)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.12/dist-packages (from statsmodels) (25.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.17.0)
# <Axes: ylabel='Resid'>

# %%
df.head()
# Out:
#    Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1 2010-02-05    1643690.90             0        42.31       2.572
# 1      1 2010-02-12    1641957.44             1        38.51       2.548
# 2      1 2010-02-19    1611968.17             0        39.93       2.514
# 3      1 2010-02-26    1409727.59             0        46.63       2.561
# 4      1 2010-03-05    1554806.68             0        46.50       2.625
#
#           CPI  Unemployment  log_weekly_sales  week  month  year
# 0  211.096358         8.106         14.312455     5      2  2010
# 1  211.242170         8.106         14.311400     6      2  2010
# 2  211.289143         8.106         14.292967     7      2  2010
# 3  211.319643         8.106         14.158908     8      2  2010
# 4  211.350143         8.106         14.256862     9      3  2010

# %%
target = 'log_weekly_sales'

# %%
df['week'] = df['week'].astype(int)

# %%
import statsmodels.api as sm

# Define the features to be used for the model
features = ['Store', 'Holiday_Flag', 'Temperature', 'Fuel_Price', 'CPI', 'Unemployment', 'week', 'month', 'year']

# Split the data using only the selected numeric features
x_train, x_test, y_train, y_test = train_test_split(df[features], df.log_weekly_sales, test_size=0.1, random_state=20)

# Convert x_train DataFrame to a NumPy array before adding the constant
x_train_with_const = sm.add_constant(x_train.values, prepend=False)
mod1=sm.OLS(y_train, x_train_with_const).fit()
print(mod1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       log_weekly_sales   R-squared:                       0.120
# Model:                            OLS   Adj. R-squared:                  0.119
# Method:                 Least Squares   F-statistic:                     87.97
# Date:                Tue, 30 Dec 2025   Prob (F-statistic):          5.23e-154
# Time:                        04:54:59   Log-Likelihood:                -4784.2
# No. Observations:                5791   AIC:                             9588.
# Df Residuals:                    5781   BIC:                             9655.
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.0143      0.001    -24.518      0.000      -0.015      -0.013
# x2             0.0244      0.029      0.833      0.405      -0.033       0.082
# x3            -0.0029      0.000     -6.698      0.000      -0.004      -0.002
# x4             0.0739      0.029      2.582      0.010       0.018       0.130
# x5            -0.0019      0.000     -8.720      0.000      -0.002      -0.001
# x6            -0.0149      0.004     -3.397      0.001      -0.024      -0.006
# x7            -0.0134      0.006     -2.316      0.021      -0.025      -0.002
# x8             0.0710      0.025      2.802      0.005       0.021       0.121
# x9            -0.0212      0.017     -1.261      0.207      -0.054       0.012
# const         56.9575     33.774      1.686      0.092      -9.252     123.168
# ==============================================================================
# Omnibus:                      421.845   Durbin-Watson:                   1.971
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              294.291
# Skew:                          -0.444   Prob(JB):                     1.25e-64
# Kurtosis:                       2.342   Cond. No.                     9.38e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.38e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# Linear Regression on Test Set

# %%
# Convert x_train DataFrame to a NumPy array before adding the constant
x_test_with_const = sm.add_constant(x_test.values, prepend=False)
mod2=sm.OLS(y_test, x_test_with_const).fit()
print(mod2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       log_weekly_sales   R-squared:                       0.140
# Model:                            OLS   Adj. R-squared:                  0.128
# Method:                 Least Squares   F-statistic:                     11.46
# Date:                Tue, 30 Dec 2025   Prob (F-statistic):           9.72e-17
# Time:                        04:55:01   Log-Likelihood:                -511.87
# No. Observations:                 644   AIC:                             1044.
# Df Residuals:                     634   BIC:                             1088.
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.0156      0.002     -8.972      0.000      -0.019      -0.012
# x2            -0.0434      0.093     -0.468      0.640      -0.225       0.138
# x3            -0.0041      0.001     -3.092      0.002      -0.007      -0.001
# x4             0.0790      0.084      0.941      0.347      -0.086       0.244
# x5            -0.0024      0.001     -3.701      0.000      -0.004      -0.001
# x6            -0.0012      0.013     -0.095      0.924      -0.027       0.024
# x7             0.0134      0.018      0.755      0.451      -0.021       0.048
# x8            -0.0418      0.077     -0.541      0.589      -0.194       0.110
# x9            -0.0383      0.050     -0.768      0.443      -0.136       0.060
# const         91.4216    100.060      0.914      0.361    -105.067     287.910
# ==============================================================================
# Omnibus:                       42.111   Durbin-Watson:                   2.029
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               27.601
# Skew:                          -0.382   Prob(JB):                     1.02e-06
# Kurtosis:                       2.334   Cond. No.                     9.50e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.5e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# Linear Regression captures only a small portion of sales variability, indicating that Walmart sales are driven by complex, non-linear and seasonal factors

# %%
from sklearn.linear_model import LassoCV
lassocv=LassoCV(cv=5)
lassocv.fit(x_train,y_train)
lassocv.alpha_
# Out:
# np.float64(0.002258378307232625)

# %%
# We can change value of alpha its on us
from sklearn.linear_model import Lasso
lasso=Lasso(alpha=0.002) # as we increase the value of alpha, Lasso becomes more aggressive (i.e. it minimizes coeff. more)
lasso.fit(x_train,y_train)
lasso.coef_
# Out:
# array([-0.01428408,  0.        , -0.00289478,  0.03171609, -0.00196124,
#        -0.01286239, -0.00642337,  0.04136105, -0.        ])

# %%
y_pred = mod1.predict(x_test_with_const)
residuals = (y_pred-y_test)

# %%
# SSE: Sum Square of Error
# SST: Sum Square of Total Variation
residuals=y_pred-y_test
SSE = sum(residuals**2)   # unexplained variation
SST = sum((y_test-np.mean(y_test))**2)   # total variation
SSR = SST - SSE  # sum of square due to regression or explained variation

#SSR: Sum of Square due to Regression

R2_Test=SSR/SST
R2_Test=1-SSE/SST

# %%
R2_Test
# Out:
# 0.13119587413919898

# %% [markdown]
# **Decision Tree**

# %%
from sklearn.tree import DecisionTreeRegressor
dtr=DecisionTreeRegressor()
dt=dtr.fit(x_train,y_train)

# %%
dtr.score(x_train,y_train)
# Out:
# 1.0

# %%
dtr.score(x_test,y_test)
# Out:
# 0.9705292540566974

# %% [markdown]
# To avoid overfitting we will now use some hyperparamters

# %%
my_params={'criterion':['squared_error', 'friedman_mse'],'max_depth':[3,4,5,6,7,10,15],
           'min_samples_split':[2,3,4,5],
           'min_samples_leaf':[2,3,4,5]}

# %%
from sklearn.model_selection import GridSearchCV
grid_model=GridSearchCV(dtr,param_grid=my_params,cv=5,scoring='accuracy')

# %%
grid_model.fit(x_train,y_train)
grid_model.best_params_
# Out:
# {'criterion': 'squared_error',
#  'max_depth': 3,
#  'min_samples_leaf': 2,
#  'min_samples_split': 2}

# %%
dtr_final = DecisionTreeRegressor(criterion='squared_error',
 max_depth=6,
 min_samples_leaf= 2,
 min_samples_split=2)

# %%
dtr_final.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=6, min_samples_leaf=2)

# %%
dtr_final.score(x_train,y_train)
# Out:
# 0.860714763661353

# %%
dtr_final.score(x_test,y_test)
# Out:
# 0.8213306186392503

# %% [markdown]
# **Random Forest**

# %%
from sklearn.ensemble import RandomForestRegressor
rfr=RandomForestRegressor()
rfr.fit(x_train,y_train)
print(rfr.score(x_train,y_train))
print(rfr.score(x_test,y_test))
# Out:
# 0.9970411579827803
# 0.9848175360692659

# %%
myparams={
    'n_estimators':[10,20,50,100,200],
    'criterion':['gini','log_loss','entropy'],

}

# %%
grid=GridSearchCV(rfr,param_grid=my_params,cv=5,scoring='accuracy')
grid.fit(x_train,y_train)
grid.best_params_

# %%
rfr_final = RandomForestRegressor(criterion='squared_error',
 max_depth=6,
 min_samples_leaf= 4,
 min_samples_split=3)

# %%
rfr_final.fit(x_train,y_train)
# Out:
# RandomForestRegressor(max_depth=6, min_samples_leaf=4, min_samples_split=3)

# %%
rfr_final.score(x_train,y_train)
# Out:
# 0.8682062452743455

# %%
rfr_final.score(x_test,y_test)
# Out:
# 0.8432449157463775

# %% [markdown]
# Random Forest (Feature Importance)

# %%
x = df.drop(['log_weekly_sales', 'Date','Weekly_Sales'], axis=1)
y= df.log_weekly_sales
from sklearn.ensemble import ExtraTreesRegressor # Changed from ExtraTreesClassifier
mod= ExtraTreesRegressor() # Changed from ExtraTreesClassifier
mod.fit(x,y)
mod.feature_importances_
feat_imp = pd.Series(mod.feature_importances_,index=x.columns)
feat_imp.plot(kind='bar')
plt.show()

# %%
df.head()
# Out:
#    Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1 2010-02-05    1643690.90             0        42.31       2.572
# 1      1 2010-02-12    1641957.44             1        38.51       2.548
# 2      1 2010-02-19    1611968.17             0        39.93       2.514
# 3      1 2010-02-26    1409727.59             0        46.63       2.561
# 4      1 2010-03-05    1554806.68             0        46.50       2.625
#
#           CPI  Unemployment  log_weekly_sales  week  month  year
# 0  211.096358         8.106         14.312455     5      2  2010
# 1  211.242170         8.106         14.311400     6      2  2010
# 2  211.289143         8.106         14.292967     7      2  2010
# 3  211.319643         8.106         14.158908     8      2  2010
# 4  211.350143         8.106         14.256862     9      3  2010

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import GradientBoostingClassifier
# !pip install xgboost
import xgboost
from xgboost import XGBRegressor
from xgboost import XGBClassifier
# Out:
# Collecting xgboost
#   Downloading xgboost-3.1.2-py3-none-manylinux_2_28_x86_64.whl.metadata (2.1 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from xgboost) (2.0.2)
# Collecting nvidia-nccl-cu12 (from xgboost)
#   Downloading nvidia_nccl_cu12-2.28.9-py3-none-manylinux_2_18_x86_64.whl.metadata (2.0 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from xgboost) (1.16.3)
# Downloading xgboost-3.1.2-py3-none-manylinux_2_28_x86_64.whl (115.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.9/115.9 MB 10.9 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.28.9-py3-none-manylinux_2_18_x86_64.whl (296.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.8/296.8 MB 1.3 MB/s eta 0:00:00
# Installing collected packages: nvidia-nccl-cu12, xgboost
# Successfully installed nvidia-nccl-cu12-2.28.9 xgboost-3.1.2

# %%
gbr = GradientBoostingRegressor()
gbr.fit(x_train,y_train)
print(gbr.score(x_train, y_train))
print(gbr.score(x_test, y_test))
# Out:
# 0.9160417413565698
# 0.9083111682384696

# %%
xgb = XGBRegressor()
mod1 = xgb.fit(x_train, y_train)
print(xgb.score(x_train, y_train))
print(xgb.score(x_test, y_test))
# Out:
# 0.99768647034688
# 0.9911399137574318

# %%
xgb = XGBRegressor(learning_rate=0.01, reg_lambda=1, reg_alpha=0.3,gamma=2,max_depth=3)
mod1 = xgb.fit(x_train, y_train)
print(xgb.score(x_train, y_train))
print(xgb.score(x_test, y_test))
# Out:
# 0.4513202663842868
# 0.4537521127480739

# %%
from sklearn.ensemble import AdaBoostRegressor
abr = AdaBoostRegressor(n_estimators=20, learning_rate=0.05, loss='linear')
mod1 = abr.fit(x_train, y_train)
print(abr.score(x_train, y_train))
print(abr.score(x_test, y_test))
# Out:
# 0.48304366247579955
# 0.48228906902080226

# %% [markdown]
# So, Gradient Boosting gives better result.

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score

# %%
models = {
    "Decision Tree": DecisionTreeRegressor(criterion='squared_error',
 max_depth=6,
 min_samples_leaf= 2,
 min_samples_split=2),
    "Random Forest": RandomForestRegressor(criterion='squared_error',
 max_depth=6,
 min_samples_leaf= 4,
 min_samples_split=3),
    "GradientBoostingRegressor": GradientBoostingRegressor(),
    "XGBRegressor": XGBRegressor(learning_rate=0.01, reg_lambda=1, reg_alpha=0.3,gamma=2,max_depth=3),
    "AdaBoostRegressor": AdaBoostRegressor(n_estimators=20, learning_rate=0.05, loss='linear')
}

# %%
scores = {}

for name, model in models.items():
    model.fit(x_train, y_train)
    y_pred = model.predict(x_test)
    scores[name] = r2_score(y_test, y_pred)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
plt.bar(scores.keys(), scores.values())
plt.ylabel("R² Score")
plt.title("Regression Model Comparison (R²)")
plt.xticks(rotation=30)
plt.show()

# %%
from sklearn.metrics import mean_squared_error
import numpy as np

rmse_scores = {}

for name, model in models.items():
    model.fit(x_train, y_train)
    y_pred = model.predict(x_test)
    rmse_scores[name] = np.sqrt(mean_squared_error(y_test, y_pred))

# %%
plt.figure(figsize=(8,5))
plt.bar(rmse_scores.keys(), rmse_scores.values())
plt.ylabel("RMSE")
plt.title("Regression Model Comparison (RMSE)")
plt.xticks(rotation=30)
plt.show()

# %% [markdown]
# Smaller the RMSE, better the model.
